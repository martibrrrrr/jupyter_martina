# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_table('differenze.txt',sep="\t",header=None)
df_csv= df.to_csv('differenze.csv')

# %%
rows=[]
with open('differenze.txt','r') as file:
    for line in file.readlines():
        values = line.strip("\n").split("\3t")
        rows.append(values)
print(rows)
# Out:
# [['27484   55634'],
#  ['67560   75018'],
#  ['43926   95501'],
#  ['86974   55714'],
#  ['71747   78366'],
#  ['28088   62509'],
#  ['34772   15990'],
#  ['29824   96324'],
#  ['29947   57910'],
#  ['98288   14717'],
#  ['65056   92495'],
#  ['51274   95004'],
#  ['77249   83538'],
#  ['47027   63476'],
#  ['38391   61559'],
#  ['70732   87324'],
#  ['48005   31948'],
#  ['78366   18349'],
#  ['61139   70973'],
#  ['73910   47466'],
#  ['20206   14717'],
#  ['22102   96393'],
#  ['88580   13914'],
#  ['54397   95954'],
#  ['49998   14239'],
#  ['61967   34634'],
#  ['12345   14607'],
#  ['41314   78200'],
#  ['21798   23855'],
#  ['98407   80316'],
#  ['86141   19452'],
#  ['73311   49491'],
#  ['81862   87593'],
#  ['95566   96160'],
#  ['87351   52582'],
#  ['15848   49491'],
#  ['51788   65164'],
#  ['35997   33641'],
#  ['47658   55714'],
#  ['81744   95501'],
#  ['47851   18884'],
#  ['43111   83702'],
#  ['11414   70973'],
#  ['40636   52220'],
#  ['27695   93149'],
# ...
